# %% [markdown]
# <a href="https://colab.research.google.com/github/iamapickle/CollisionReport/blob/master/HousePrices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.environ['KAGGLE_USERNAME'] = "siddhants150"
os.environ['KAGGLE_KEY'] = "9971f6fc5bc071ab44090a6a93c3d107"

# %%
# !kaggle competitions download -c house-prices-advanced-regression-techniques
# Out:
# ...
#   0% 0.00/31.2k [00:00<?, ?B/s]
# 100% 31.2k/31.2k [00:00<00:00, 25.2MB/s]
# ...
#   0% 0.00/450k [00:00<?, ?B/s]
# 100% 450k/450k [00:00<00:00, 62.0MB/s]
# ...
#   0% 0.00/13.1k [00:00<?, ?B/s]
# 100% 13.1k/13.1k [00:00<00:00, 13.2MB/s]
# ...
#   0% 0.00/441k [00:00<?, ?B/s]
# 100% 441k/441k [00:00<00:00, 59.4MB/s]

# %%
df_test = pd.read_csv("./test.csv")
df_train = pd.read_csv("./train.csv")

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
df_train.corr()
# Out:
#                      Id  MSSubClass  LotFrontage  ...    MoSold    YrSold  SalePrice
# Id             1.000000    0.011156    -0.010601  ...  0.021172  0.000712  -0.021917
# MSSubClass     0.011156    1.000000    -0.386347  ... -0.013585 -0.021407  -0.084284
# LotFrontage   -0.010601   -0.386347     1.000000  ...  0.011200  0.007450   0.351799
# LotArea       -0.033226   -0.139781     0.426095  ...  0.001205 -0.014261   0.263843
# OverallQual   -0.028365    0.032628     0.251646  ...  0.070815 -0.027347   0.790982
# OverallCond    0.012609   -0.059316    -0.059213  ... -0.003511  0.043950  -0.077856
# YearBuilt     -0.012713    0.027850     0.123349  ...  0.012398 -0.013618   0.522897
# YearRemodAdd  -0.021998    0.040581     0.088866  ...  0.021490  0.035743   0.507101
# MasVnrArea    -0.050298    0.022936     0.193458  ... -0.005965 -0.008201   0.477493
# BsmtFinSF1    -0.005024   -0.069836     0.233633  ... -0.015727  0.014359   0.386420
# ...

# %%
df_train.isna().any()
# Out:
# Id               False
# MSSubClass       False
# MSZoning         False
# LotFrontage       True
# LotArea          False
# Street           False
# Alley             True
# LotShape         False
# LandContour      False
# Utilities        False
# LotConfig        False
# LandSlope        False
# Neighborhood     False
# Condition1       False
# Condition2       False
# BldgType         False
# HouseStyle       False
# OverallQual      False
# OverallCond      False
# YearBuilt        False
# YearRemodAdd     False
# RoofStyle        False
# RoofMatl         False
# Exterior1st      False
# Exterior2nd      False
# MasVnrType        True
# MasVnrArea        True
# ExterQual        False
# ExterCond        False
# Foundation       False
# BsmtQual          True
# BsmtCond          True
# BsmtExposure      True
# BsmtFinType1      True
# BsmtFinSF1       False
# BsmtFinType2      True
# BsmtFinSF2       False
# BsmtUnfSF        False
# TotalBsmtSF      False
# Heating          False
# ...

# %%
# df_train.dropna(subset = ["LotFrontage"], inplace=True)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_train.corr(), cmap='YlGnBu')
plt.show()

# %%
for col in df_train:
  if df_train[col].dtypes==object:
    df_train[col] = df_train[col].astype(str)

# %%
fig, ax = plt.subplots(1, figsize=(25, 8))
sns.catplot(x='OverallQual', palette="pastel", edgecolor=".6", data=df_train, ax=ax, kind="count")
plt.close(1)
fig.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3762: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)

# %%
fig, ax = plt.subplots(1, figsize=(45, 20))
sns.scatterplot(x="LotArea", y="SalePrice", data=df_train, ax=ax, size='LotFrontage')

# %%
fig, ax = plt.subplots(1, figsize=(25, 8))
ax = sns.scatterplot(x="LotFrontage", y="SalePrice", data=df_train, hue='LotArea')

# %%
ax = sns.lineplot(x='YearBuilt', y='SalePrice', data=df_train)

# %%
ax = sns.lineplot(x='YearRemodAdd', y='SalePrice', data=df_train)

# %%
fig, ax = plt.subplots(1, figsize=(25, 8))
ax = sns.lineplot(x='TotalBsmtSF', y='SalePrice', data=df_train)

# %%
fig, ax = plt.subplots(1, figsize=(25, 8))
ax = sns.lineplot(x='FullBath', y='SalePrice', data=df_train)

# %%
fig, ax = plt.subplots(1, figsize=(25, 8))
ax = sns.lineplot(x='KitchenAbvGr', y='SalePrice', data=df_train)

# %%
fig, ax = plt.subplots(1, figsize=(25, 8))
ax = sns.lineplot(x='Fireplaces', y='SalePrice', data=df_train)

# %%
fig, ax = plt.subplots(1, figsize=(25, 8))
ax = sns.lineplot(x='GarageYrBlt', y='SalePrice', data=df_train)

# %%
fig, ax = plt.subplots(1, figsize=(25, 8))
ax = sns.lineplot(x='GarageCars', y='SalePrice', data=df_train)

# %%
fig, ax = plt.subplots(1, figsize=(25, 8))
ax = sns.lineplot(x='GarageArea', y='SalePrice', data=df_train)

# %%
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()

# %%
LE.fit()
